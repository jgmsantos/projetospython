# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('../dados/NetCDF/precip.mon.mean.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 72, lon: 144, time: 520, nv: 2)
# Coordinates:
#   * lat        (lat) float32 -88.75 -86.25 -83.75 -81.25 ... 83.75 86.25 88.75
#   * lon        (lon) float32 1.25 3.75 6.25 8.75 ... 351.2 353.8 356.2 358.8
#   * time       (time) datetime64[ns] 1979-01-01 1979-02-01 ... 2022-04-01
# Dimensions without coordinates: nv
# Data variables:
#     time_bnds  (time, nv) datetime64[ns] ...
#     lat_bnds   (lat, nv) float32 ...
#     lon_bnds   (lon, nv) float32 ...
#     precip     (time, lat, lon) float32 ...
# Attributes: (12/18)
#     Conventions:           CF-1.0
#     curator:               Dr. Jian-Jian Wang\nESSIC, University of Maryland ...
#     citation:              Adler, R.F., G.J. Huffman, A. Chang, R. Ferraro, P...
#     title:                 GPCP Version 2.3 Combined Precipitation Dataset (F...
#     platform:              NOAA POES (Polar Orbiting Environmental Satellites)
# ...

# %%
plt.figure(figsize=(12,5))  # Tamanho da figura.

ds.precip.mean(dim=('lon', 'time')).plot(label='Clima', color='black')
ds.precip.sel(time=slice('2019-12-01', '2020-02-01')).mean(dim=('lon', 'time')).plot(label='DJF', color='blue')
ds.precip.sel(time=slice('2020-06-01', '2020-08-01')).mean(dim=('lon', 'time')).plot(label='JJA', color='green')

plt.title('Média Zonal de Precipitação')

plt.legend()
